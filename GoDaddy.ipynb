# %%
import pandas as pd
import numpy as np

# %%
census_starter = pd.read_csv('census_starter.csv')

# %%
census_starter.head()
# Out:
#    pct_bb_2017  pct_bb_2018  pct_bb_2019  pct_bb_2020  pct_bb_2021  cfips  \
# 0         76.6         78.9         80.6         82.7         85.5   1001
# 1         74.5         78.1         81.8         85.1         87.9   1003
# 2         57.2         60.4         60.5         64.6         64.6   1005
# 3         62.0         66.1         69.2         76.1         74.6   1007
# 4         65.8         68.5         73.0         79.6         81.0   1009
#
#    pct_college_2017  pct_college_2018  pct_college_2019  pct_college_2020  \
# 0              14.5              15.9              16.1              16.7
# 1              20.4              20.7              21.0              20.2
# 2               7.6               7.8               7.6               7.3
# 3               8.1               7.6               6.5               7.4
# 4               8.7               8.1               8.6               8.9
#
#    ...  pct_it_workers_2017  pct_it_workers_2018  pct_it_workers_2019  \
# ...

# %%
train = pd.read_csv('train.csv')

# %%
train.head()
# Out:
#             row_id  cfips          county    state first_day_of_month  \
# 0  1001_2019-08-01   1001  Autauga County  Alabama         2019-08-01
# 1  1001_2019-09-01   1001  Autauga County  Alabama         2019-09-01
# 2  1001_2019-10-01   1001  Autauga County  Alabama         2019-10-01
# 3  1001_2019-11-01   1001  Autauga County  Alabama         2019-11-01
# 4  1001_2019-12-01   1001  Autauga County  Alabama         2019-12-01
#
#    microbusiness_density  active
# 0               3.007682    1249
# 1               2.884870    1198
# 2               3.055843    1269
# 3               2.993233    1243
# 4               2.993233    1243

# %%
test = pd.read_csv('test.csv')

# %%
test.head()
# Out:
#             row_id  cfips first_day_of_month
# 0  1001_2022-11-01   1001         2022-11-01
# 1  1003_2022-11-01   1003         2022-11-01
# 2  1005_2022-11-01   1005         2022-11-01
# 3  1007_2022-11-01   1007         2022-11-01
# 4  1009_2022-11-01   1009         2022-11-01

# %%
train.head()
# Out:
#             row_id  cfips          county    state first_day_of_month  \
# 0  1001_2019-08-01   1001  Autauga County  Alabama         2019-08-01
# 1  1001_2019-09-01   1001  Autauga County  Alabama         2019-09-01
# 2  1001_2019-10-01   1001  Autauga County  Alabama         2019-10-01
# 3  1001_2019-11-01   1001  Autauga County  Alabama         2019-11-01
# 4  1001_2019-12-01   1001  Autauga County  Alabama         2019-12-01
#
#    microbusiness_density  active
# 0               3.007682    1249
# 1               2.884870    1198
# 2               3.055843    1269
# 3               2.993233    1243
# 4               2.993233    1243

# %%
# pct_bb: percentage of households with access to broadband
# pct_college: percentage of people over age 25 with a degree
# pct_foreign_born: percentage of people born outside US
# pct_it_workers: percentage of workforce in tech
# median_hh_inc: median household income for the county
# active: raw number of small businesses in the county
# microbusiness_density: target variable

# %%
# we have both the raw number of businesses and density. eventually check if one can be dropped

# %%
# there is a two year lag in the data. revisit this later please

# %%
# row_id is useless
# county name is redundant for now

train.drop(['row_id', 'county'], axis = 1, inplace = True)

# %%
train.head()
# Out:
#    cfips    state first_day_of_month  microbusiness_density  active
# 0   1001  Alabama         2019-08-01               3.007682    1249
# 1   1001  Alabama         2019-09-01               2.884870    1198
# 2   1001  Alabama         2019-10-01               3.055843    1269
# 3   1001  Alabama         2019-11-01               2.993233    1243
# 4   1001  Alabama         2019-12-01               2.993233    1243

# %%
# group by cfips
# if you are serious about this competition you will likely need more census data and hope they use the same cfips number
